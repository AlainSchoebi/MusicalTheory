# %% [markdown]
# # Milestone 2

# %% [markdown]
# # Imports

# %%
import random                  
from fractions import Fraction   
import functools
import math
import numpy as np
import matplotlib.pyplot as plt
from music21 import chord, corpus, environment, meter, midi, note, stream, tempo, dynamics, instrument, key, duration
from IPython.display import Audio
import time
random.seed(time.time())

# %% [markdown]
# ### MuseScore3 Windows
# ##### Run the following cell if you are using this file on a Windows

# %%
# Windows (adapt Program Files)
musescore_executable = r'C:\Program Files\MuseScore 3\bin\MuseScore3.exe'

environment.set('musescoreDirectPNGPath', musescore_executable)
environment.set('musicxmlPath', musescore_executable)
environment.set('autoDownload', 'allow')

# %% [markdown]
# ### MuseScore3 Mac
# ##### Run the following cell if you are using this file on a Mac

# %%
# Mac path
musescore_executable = '/Applications/MuseScore 3.app/Contents/MacOS/mscore'

environment.set('musescoreDirectPNGPath', musescore_executable)
environment.set('musicxmlPath', musescore_executable)
environment.set('autoDownload', 'allow')

# %% [markdown]
# # **1) Brief Overview**
# ##### In this step of the composition we decided to use mostly python as our intention, as stated in Milestone1, was to create an aleatoric music. To do this it was necessary to code functions and classes that generate aleatoric notes and rhythms. This is feasible on JupyterLab by using the Music21 repertoire and mathematical tools, including the random repertoire. We will also be using Music21 instruments (piano, guitare, violin, flute and contrabass) for our composition. Furthermore we used Audacity to modify audios from youtube that we will be adding to our piece in future steps. The use of these Audio files has not been mentioned in Milestone but we decided to add them to represent the seasons better. Audacity is being used as it the modifications done on the audio files is the deletion of background noise and the change of pitch which are two functions offered by the program.

# %% [markdown]
# # **2) Main section with one subsection per sub-structure**
# ##### The general goal of this project is to create well structured and well sounding algorithmic music that imitates handwritten musical piece rules. As it would be described more explicitly later, the pitch of one note finely depends on the one of the previous note to avoid enormous gaps in order not to break the fragile harmony supervising the melody. To implement that idea, we used a gaussian distribution to assign different probabilities depending on how far the next note’s pitch can be. In a similar way, we can attribute specific appearance’s frequency to each rhythm. Other specificities of our piece will be described in more detail below.
# ##### As we have not discarded many outputs we will list examples here. As explained in the first paragraph, we tried to tune our algorithms to produce a natural continuation of pitches and rhythms. We first tried without any appropriate rules, but the sound and structure did not satisfy our ears. For our second try, which is the current one, we added many rules in forms of functions or by adding conditions inside of pre-existing functions. Some of the rules will be explicitly explained in the following cells.

# %% [markdown]
# # Tools
# ##### The tools or funcitons below do not belong to a specific subsection but will be used throughout the whole code.

# %% [markdown]
# ## Music Tools
# ##### The following functions will be used in the code.

# %%
# function to return key for any value - This function will be used in the class chord
def getKeyFromValue(_dictionnary, _value):
    for key, value in _dictionnary.items():
         if _value == value:
             return key
 
    return None; #doesn't exist

#Shortcut to play a stream
def play(score):
    midi.realtime.StreamPlayer(score).play();
    
#This function takes two notes and checks whether they represent the same note without looking at the octave. It returns true if they represent the same note and false otherwise
def isSameNoteWithoutOctave(note1, note2):
    
    if note1.pitch.name == note2.pitch.name: 
        return True;
    
    # To lose the octave information
    n1 = note.Note(pitch = note1.pitch.name);
    n2 = note.Note(pitch = note2.pitch.name);
    
    if n1.pitch.frequency == n2.pitch.frequency:
        return True;
    
    return False;


# Concatenete two parts (with differents music21 Objects)
def concatParts(_part1, _part2, _bpm = None):     
    cPart = stream.Part();
    cPart.append(_part1.elements);
    cPart.append(_part2.elements);  
    if _bpm != None:
        cPart.append(tempo.MetronomeMark(number = _bpm)); 
    return cPart;

# Concatenete two scores (with differents music21 Objects)
def concatScores(_score1, _score2, _bpm = None): # must have same number of parts !
    cScore = stream.Score();
    L = len(_score1.parts);
    if L != len(_score2.parts):
        print("Different number of parts !");
    for i in range(L):
        cPart = concatParts(_score1.parts[i], _score2.parts[i], _bpm);
        cScore.insert(0, cPart);
    return cScore;

# %%
stream2 = stream.Stream()
n3 = note.Note('D#5') # octave values can be included in creation arguments
stream2.repeatAppend(n3, 4)
stream2.show()

# %% [markdown]
# ##### Example using the function *isSameNoteWithoutOctave()*

# %%
d = note.Note("D#3");
e = note.Note("Eb5");

print(isSameNoteWithoutOctave(d,e));
# Out:
# True

# %% [markdown]
# ## Math Tools

# %%
def gaussParameter(x, doubleSigma, mu): # with value 1 at x = mu
    sigma = doubleSigma/2;
    return math.exp(-1/2*(x-mu)**2/sigma**2); #1/sigma/math.sqrt(2*math.pi)*

def gaussFunction(doubleSigma, mu = 0):
    return functools.partial(gaussParameter, mu = mu, doubleSigma = doubleSigma);

def intervalParameter(x, a):
    if x >= -a and x <= a:
        return 1;
    return 0;

def intervalFunction(a):
    return functools.partial(intervalParameter, a=a)

# %% [markdown]
# ##### Example using the interval function and the gauss function. We apply the functions to 100 values of x ranging from -20 to 20. The interval between each value for x is equal. Then we plot the graphs corresponding to each function.

# %%
x = np.linspace(-20,20,100);
y = np.zeros(len(x));


f = intervalFunction(5);

for i in range(len(x)):
    y[i] = f(x[i]);

plt.plot(x,y, 'r');
plt.title('Interval Function')
plt.show();


f = gaussFunction(5);

for i in range(len(x)):
    y[i] = f(x[i]);

plt.plot(x,y, 'b');
plt.title('Gauss Function')
plt.show();

# %% [markdown]
# # Scale
# ##### As mentioned in milestone 1, Vivaldi uses a specific scale for each season. As this is an aspect of the Four Seasons that we wanted to incorporate in our own interpretation of the piece, we have decided to create a class called Scale. The scale will be constructed based on a base note and the type of scale (major, minor, dorian or else). The same class can also generate a scale from a random base and random type.

# %% [markdown]
# ### Scales interval dictionnary
# ##### Scales interval dictionnary links the name of the scale and the amount of numbers between each note starting from the base note

# %%
scalesIntervalDictionnary = {
  "major": [0,2,4,5,7,9,11],
  "minor": [0,2,3,5,7,8,10]
}

# %% [markdown]
# ### Scale class
# ##### Scale is a class generating a musical scale / a range starting from the base note and the type of scale (major, minor, dorian or else). It can also generate a scale from a random base and random type.

# %%
class Scale:
    
    # Constructor
    def __init__(self, _baseNote = note.Note('C4'), _interval = scalesIntervalDictionnary["major"], _randomBase = False, _randomMinorMajorScale = False):
              
        if _randomBase == True:
            self.baseNote = note.Note(pitch = random.randint(0,11));
        else: 
            self.baseNote = _baseNote;
             
        if _randomMinorMajorScale == True:
            r = random.randint(0,1);
            if r == 1:
                self.interval = scalesIntervalDictionnary["major"];
            else:
                self.interval = scalesIntervalDictionnary["minor"];
        else:
            self.interval = _interval;
    
    # Gets the ith tone of the scale, i = 1 returns the fundamental, i = 2 returns the "seconde"
    def getTone(self, i):
        return self.baseNote.transpose(self.interval[(i-1)%len(self.interval)]);
    
    # Get notes of the scale without considering the octave
    def getNotesWithoutOctave(self):       
        n = [self.baseNote.transpose(i) for i in self.interval];
        return n;
    
    # is the given ton on the scale
    def isToneOnScale(self, note):
        for i in range(len(self.interval)):
            if isSameNoteWithoutOctave(self.baseNote.transpose(self.interval[i]), note):
                return True;
        return False;
    
    # is Minor if the third minor is on the scale
    def isMinor(self):
        return self.isToneOnScale(self.baseNote.transpose(3));
    
    # is Major if the third major is on the scale
    def isMajor(self):
        return self.isToneOnScale(self.baseNote.transpose(4));
    
    
    # show is a function that shows all the notes of the scale.
    def show(self):   
        text = self.baseNote.pitch.name;
        if self.isMajor():
            text += " major";
        if self.isMinor():
            text += " minor";
        print(text, self.interval);  
        
        m = stream.Measure();
        m.append([self.baseNote.transpose(i) for i in self.interval]);     
        m.append(self.baseNote.transpose(12));
        m.show();

# %% [markdown]
# ### Example of a scale
# ##### In this example we construct a scale 's' base on the note 'C' and the type 'major'. We get the third tone of the scale by calling the function getTone and show it. It is the first outcome visible. Then we want to check that the scale constructed is a major scale like we intended to. So we call the isMinor function to make sure it is not a minor scale. In our piece we only have minor and major scales and therefore if it isn't minor it is major. And as we can see in the outcome it is indeed not a minor sclae as the function isMinor returns false. We then want to show our scale by printing its name, its note intervals and the actual notes on the score.

# %%
s = Scale(note.Note("C"), scalesIntervalDictionnary["major"]);
s.getTone(3).show() # la tierce
print("minor:", s.isMinor())
s.show();
# Out:
# minor: False
# C major [0, 2, 4, 5, 7, 9, 11]

# %% [markdown]
# # Chord
# ##### As we had the intention to write a piece with multiple instruments we decided that it would be good to have the piano play chords to accompany the main melody which is played by the main instrument. So we decided to compute a class called Chord which will enable us to generate chords based on the base note and a scale.

# %% [markdown]
# ### Chords type dictionnary

# %%
chordsDictionnary = {
  "": [0,4,7],
  "5": [0,7],
  "m": [0,3,7],
  "7": [0,4,7,10],
  "m7": [0,3,7,10]
}

# %% [markdown]
# ### Chord Class
# ##### Chord is a class constructing a chord based on a base note and a scale

# %%
class Chord:
    
    # Constructor
    def __init__(self, _baseNote, _scale):

        self.baseNote = _baseNote;
        self.interval = [0]; # 1th and 5th
        
        if _scale.isToneOnScale(_baseNote.transpose(3)) == True:
            self.interval.append(3);
        elif _scale.isToneOnScale(_baseNote.transpose(4)) == True:           
            self.interval.append(4);
            
        self.interval.append(7);
        
    def copy(self):
        b = note.Note(pitch = self.baseNote.pitch.name);
        c = Chord(b, Scale());
        c.interval = self.interval;
        return c;
                
    # Define (like a constructor)
    def defineByType(self, _baseNote, _type = ""):       
        self.baseNote = _baseNote;
        self.interval = chordsDictionnary[_type];
            
            
    def getType(self):
        key = getKeyFromValue(chordsDictionnary, self.interval);
        if key != None:
            return key;
        return "Not in dictionnary";    
    
    def getName(self):
        return self.baseNote.name + self.getType();
    
    # Get notes
    def getNotesWithoutOctave(self):       
        n = [self.baseNote.transpose(i) for i in self.interval];
        return n;    
    
    def getNotesWithOctave(self, _octave = 4, _quarterLength = 1):       
        n = [note.Note(pitch = self.baseNote.transpose(i).pitch.name, octave = _octave, quarterLength = _quarterLength) for i in self.interval];
        return n;    
    
    def getNotesWithOctaveIncreasingOrder(self, _octave = 4, _quarterLength = 1):   
        thatBaseNote = note.Note(pitch = self.baseNote.pitch.name, octave = _octave, quarterLength = _quarterLength);
        n = [thatBaseNote.transpose(i) for i in self.interval]
       # n = [note.Note(pitch = self.baseNote.transpose(i).pitch.name, quarterLength = _quarterLength) for i in self.interval];
        
        return n;    
    
    def getChordObject(self,  _octave = 4, _quarterLength = 1):
        return chord.Chord(self.getNotesWithOctave(_octave = _octave, _quarterLength = _quarterLength));
    
    # Show
    def show(self):
        self.getChordObject().show();
        
    def getText(self):
        return self.baseNote.pitch.name + " " + self.getType();
        
    def showText(self):
        print(self.getText());

# %% [markdown]
# ### Example of a chord construction
# ##### The chord is constructed based on the note F and the scale s defined in the previous example (cf Example of a scale). To make sure our chord is correctly constructed we will print as many information about it as possible. First we show the chord on a score. We also print its name, the intervals betwen each note (4 means that there are 4 semitones between the first and second note of the chord and 7 means that there are 7 semitones between the first and third note of the chord). We also print the notes in music21.note.Note format. We can see in the results that the notes of the chord are F, A and C. To go even further, we wanted to show that there is a possibility to change the duration of our chord which is represented on the second score.

# %%
c = Chord(_baseNote = note.Note("F"), _scale = s);
c.show();
print(c.getName());
print(c.interval)
print(c.getNotesWithOctave())
c.getChordObject(_quarterLength = 4).show();
# Out:
# F
# [0, 4, 7]
# [<music21.note.Note F>, <music21.note.Note A>, <music21.note.Note C>]

# %% [markdown]
# # NotesRange
# ##### Now that we have scales and chords we want to have a certain control over which note is more likely to be played in our melody. For example we might want to eliminate very high and low notes or maybe increase the probability of C5 to be played. In order to gain this control over our piece we decided to create a class called NotesRange which has multiple multiple functions that change the probability of a certain note appearing in our melody.

# %% [markdown]
# ### NotesRange Class

# %%
class NotesRange:
    
    # Constructor
    def __init__(self, _octaveNumber = 8):  
        
        self.range = {}; # Dictionnary
        for o in range(_octaveNumber):
            for i in range(0,12):
                n = note.Note(pitch = i);
                self.range[n.pitch.name + str(o)] = 0;   
        
        self.range["C" + str(o+1)] = 0; # highest C
                
                
    # Add chance/probability to notes (without octave) 
    # if _probability is empty, then all notes' probability will be increased by 1 
    def addChanceToNotesWithoutOctave(self, _notes = [], _probabilities = [], _probability = 1):
        
        if len(_notes) != 0 and len(_probabilities) < len(_notes):
            _probabilities = [_probability for i in _notes];
        
        for key in self.range:
            for x in range(len(_notes)):
                if isSameNoteWithoutOctave(note.Note(key), _notes[x]) == True:
                    self.range[key] += _probabilities[x];
        return;
   
    def addOtherNotesRange(self, _noteRange):
        for key in self.range:
            self.range[key] += _noteRange.range[key];
        return; 
    
    
    
    
    def multiplyChanceToNotesWithoutOctave(self, _notes = [], _probabilities = [], _probability = 1):
        
        if len(_notes) != 0 and len(_probabilities) < len(_notes):
            _probabilities = [_probability for i in _notes];
        
        for key in self.range:
            for x in range(len(_notes)):
                if isSameNoteWithoutOctave(note.Note(key), _notes[x]) == True:
                    self.range[key] *= _probabilities[x];
        return;
    
    
    # Mulitiply by a function. 0 is the _zeroNote and then +1 for the next note etc, 12 is the distance for an octave
    def multiplyByFunction(self, _function, _zeroNote = note.Note("C4")):              
        keysLength = len(self.range.keys());
        for key in self.range.keys():             
            x = note.Note(key).pitch.midi - _zeroNote.pitch.midi;                     
            #print(key + "  " + str(x) + " f(x): " + str(_function(x)))
            self.range[key] *= _function(x);   
            
    def pickRandomNote(self):
        totalProbability = 0;
        for key in self.range.keys(): 
            totalProbability += self.range[key];
        
        if totalProbability == 0:
            print("NotesRange.pickRandomNote() has no solution!");
            self.showPlot();
        
        r = random.uniform(0,totalProbability);
        #print(str(totalProbability) +"  " + str(r));
        
        counter = 0;
        for key in self.range.keys():
            counter += self.range[key];
            if counter >= r:
                return note.Note(key);          
        return None; # empty notesRange
    
    # Show 
    def show(self):
        print(self.getText());
        
    # Get Text for show()
    def getText(self):
        txt = "{ ";
        for key in self.range.keys():
            value = self.range[key];
            if value != 0:
                txt += key + ": " + str(value) + ", ";
                
        if txt == "{ ":
            return "{ empty NotesRange }";
        return txt[:-2] + " }";
        
    # Show Plot
    def showPlot(self):
        keys = self.range.keys();
        values = self.range.values();
        plt.bar(keys, values);

# %% [markdown]
# ### Example for NotesRange class
# ##### In this example we first construct a NotesRange element (nr) and add probabilities to the notes C and D. We then create a function and multiply the probabilities using this function. In the plot you can see that a lot of notes have probability 0.This means that when generating a piece made from those notes, only the ones with a probability bigger than zero will be generated. The likelihood of them appearing will be proporitonate to their probability.

# %%
nr = NotesRange();

nr.addChanceToNotesWithoutOctave([note.Note("C"),note.Note("D")], [2,15]);

def ff(x): 
    if x < 0:
        return 0;
    if x == 0:
        return 5;
    return 3;


nr.multiplyByFunction(ff);
nr.showPlot();
nr.show()
nr.addOtherNotesRange(nr)
nr.show()
# Out:
# { C4: 10, D4: 45, C5: 6, D5: 45, C6: 6, D6: 45, C7: 6, D7: 45, C8: 6 }
# { C4: 20, D4: 90, C5: 12, D5: 90, C6: 12, D6: 90, C7: 12, D7: 90, C8: 12 }

# %% [markdown]
# ### Example using scales, chords and notes range
# ##### First we generate a C major scale. Then we create a list of notes and chords to which we add the bass note (C). We then generate a notesRange with plenty of rules that will apply to the notes and chrods. Following that we create and display a score which shows the chords and notes we generated. As you can see from this score, the notes we generated are always found in its corresponding chord.

# %%
s = Scale(note.Note("C"), scalesIntervalDictionnary["major"]);
s.show();

# input
octaveRegion = 2;
nbr = 8;
bassNotes = [];  # stores music21's note.Note()
bassChords = []; # stores Chord objects

bassNotes.append(note.Note(pitch = s.baseNote.pitch.name, octave = octaveRegion)); # bassNotes[0]
bassChords.append(Chord(bassNotes[0], s));                                         # bassChords[0]

print("\nNotesRange:")
for i in range(nbr): 
    
    # Bass Rules
    nr = NotesRange();
    nr.addChanceToNotesWithoutOctave(s.getNotesWithoutOctave()); # notes of the scale
    
    if s.isMinor():
        nr.multiplyChanceToNotesWithoutOctave([s.getTone(2)], _probability = 0);
    if s.isMajor():
        nr.multiplyChanceToNotesWithoutOctave([s.getTone(7)], _probability = 0);
        
    nr.multiplyChanceToNotesWithoutOctave(bassChords[i].getNotesWithoutOctave(), _probability = 3); # notes of the chord from the bassNotes[i]
    nr.multiplyChanceToNotesWithoutOctave([bassNotes[i]], _probability = 0); # avoir playing the same bassNotes[i] again
    nr.multiplyByFunction(intervalFunction(6), note.Note(pitch = 6, octave = octaveRegion)); # range, to stay in the octaveRegion
    
    
    nr.showPlot();
    print(i, nr.getText());
    bassNotes.append(nr.pickRandomNote());     #bassNotes[i+1]
    bassChords.append(Chord(bassNotes[i+1], s)); #bassChords[i+1]
    

print("\nChords:")
score = stream.Score()

measureBassNotes = stream.Part();
measureBassChords = stream.Part();

score.insert(0, measureBassChords);
score.insert(0, measureBassNotes);

for i in range(nbr):
    print(i, bassChords[i].getText(), bassChords[i].getNotesWithoutOctave());  
    measureBassChords.append(bassChords[i].getChordObject());
    measureBassNotes.append(bassNotes[i]);

score.show();
play(score);
# Out:
# C major [0, 2, 4, 5, 7, 9, 11]
# NotesRange:
# 0 { D2: 1, E2: 3, F2: 1, G2: 3, A2: 1 }
# 1 { C2: 1, D2: 3, E2: 1, F2: 1, A2: 1, C3: 1 }
# 2 { C2: 3, D2: 1, E2: 3, F2: 1, G2: 1, C3: 3 }
# 3 { D2: 1, E2: 3, F2: 1, G2: 3, A2: 1 }
# 4 { C2: 1, D2: 1, F2: 1, G2: 3, A2: 1, C3: 1 }
# 5 { C2: 1, D2: 3, E2: 1, F2: 1, A2: 1, C3: 1 }
# 6 { C2: 1, D2: 1, F2: 1, G2: 3, A2: 1, C3: 1 }
# 7 { C2: 1, D2: 3, E2: 1, F2: 1, A2: 1, C3: 1 }
#
# Chords:
# 0 C  [<music21.note.Note C>, <music21.note.Note E>, <music21.note.Note G>]
# 1 G  [<music21.note.Note G>, <music21.note.Note B>, <music21.note.Note D>]
# 2 A m [<music21.note.Note A>, <music21.note.Note C>, <music21.note.Note E>]
# 3 C  [<music21.note.Note C>, <music21.note.Note E>, <music21.note.Note G>]
# 4 E m [<music21.note.Note E>, <music21.note.Note G>, <music21.note.Note B>]
# 5 G  [<music21.note.Note G>, <music21.note.Note B>, <music21.note.Note D>]
# 6 E m [<music21.note.Note E>, <music21.note.Note G>, <music21.note.Note B>]
# ...

# %% [markdown]
# # Rhythm Generation
# ##### We also decided to generate a random rhythm to accompany our random sequence of notes. To achieve that we decided to compute a code inspired by the Markov tree but by interpreting and changing it according to what was more intuitive to us. The functions we wrote would generate a sequence of random numbers and transform those in note durations and rests according to some conditions carefully chosen by us. For example one rule that this generation should follow is to prevent the piece to start with rests. Another rule is to make sure that the rhythm is clean. This means that we will never have a note overlapping from one bar to the next.

# %%
def create_percussion(time_sig = None):
    if time_sig == None:
        drumPart = stream.Measure()
    else:
        drumPart = stream.Stream()
        drumPart.timeSignature = meter.TimeSignature(time_sig)
    
    drumPart.insert(0, instrument.TomTom())
    return drumPart

def append_event(duration, original_stream, rest = False, pitch = "C4"):
    new_stream = original_stream
    if rest:
        new_stream.append(note.Rest(quarterLength = duration*4))
    else:
        new_stream.append(note.Note(pitch, quarterLength = duration/4))
                          
    return new_stream

def rhythm_from_sequence(durations, time_sig = None, pitch = 'C4', rhythm=None):
    if rhythm is None:
        rhythm = create_percussion(time_sig = time_sig)
                          
    for dur in durations:
        is_rest = False
        if dur != 0:
            if dur < 1:
                is_rest = True
                dur = Fraction(dur)
            
            rhythm = append_event(dur, rhythm, rest = is_rest, pitch = pitch) 
    return rhythm

# %% [markdown]
# ## The tree

# %% [markdown]
# ### Constants
#
# ##### The number of the arr list below represent the following note values:
# * 1: sixteenth note
# * 2: eighth note
# * 4: quarter note
# * 8: half note
# * 16: whole note
# * 1/2: half rest
# * 1/4: quarter rest
# * 1/8: eighth rest

# %%
arr = [1, 2, 4, 8, 16, 1/2, 1/4, 1/8]; 
freq = [5, 50, 30, 20, 10, 3, 2, 1]

# %% [markdown]
# ### Functions generation of random rythme
# ##### Four functions have been written in order to create the random rhythm. They have been annotated directly in the cell.

# %%
# Function use to find the corresponding index of r 
def findCeil(arr, r, l, h) :
 
    while (l < h) :   
        mid = l + ((h - l) >> 1);
        if r > arr[mid] :
            l = mid + 1
        else :
            h = mid
     
    if arr[l] >= r:
        return l
    else :
        return -1

# Function use to populate the list prefix and generating a random number according to the frequency
def myRand(arr, freq, n):
    prefix = [0] * n
    prefix[0] = freq[0]
    for i in range(n):
        prefix[i] = prefix[i - 1] + freq[i]
    
    #random number from 1 to the sum of all frequencies
    r = random.randint(0, prefix[n - 1]) + 1 
    
    # the index of one the number in arr corresponding to r
    indexc = findCeil(prefix, r, 0, n - 1)
    return arr[indexc]

# Function use to generate the main tree
    # nodelist     the nodes in the tree; each node is a list with elements [idx, parent, depth, rdm number]
    # idx          the index of a node
    # parent       the index of the node's parent
    # depth        the distance of a node from the root
    # max_children the maximum number of children a node can have
    # max_depth    the maximum distance from the tree to the root
def generate_random_tree(arr=[], freq=[], nodelist=[], idx=0, parent=None, depth=0, max_children=4, max_depth=4):
    notes = []
    ryth = []
    for i in range(len(arr)) :
        if freq[i] != 0:
            notes.append(arr[i])
            ryth.append(freq[i])
            
    if 0 <= depth < max_depth: 
        # adds a random number of children, it must have at least one child
        n = random.randint(1, max_children)
        nodelist.extend([[idx+i, parent, depth, myRand(notes, ryth, len(notes))] for i in range(n)])  

        [generate_random_tree(arr, freq, nodelist, len(nodelist), idx+i, depth+1, max_children, max_depth) 
                              for i in range(n)]

    elif depth == max_depth:
        n = random.randint(1, max_children)
        nodelist.extend([[idx+i, parent, depth, myRand(notes, ryth, len(notes))] for i in range(n)])  
        return
    
     
def get_path(frequence):
    tree = [[0, None, 0, 1]]
    generate_random_tree(arr, frequence, nodelist=tree, idx=len(tree), parent=0, depth=1, max_children=3, max_depth=10)

    parent = 0
    path = []
    child = []
    children = 0
    measureCount = 0
       
    while children == 0:
        children = 1

        for x in range(len(tree)):
            if tree[x][1] == parent: 
                child.append(tree[x][0])
                children = 0
        if child:
            rdm = child[random.randint(0, len(child)-1)]
            actualPath = tree[rdm][3]
            if measureCount == 4:
                measureCount = 0
            if actualPath >= 1:
                if (measureCount + (actualPath/4)) <= 4:
                    path.append(actualPath)
                    measureCount += (actualPath/4)
                else:
                    path.append((4 - measureCount)*4)
                    measureCount = 0
                    path.append(actualPath)
                    measureCount += (actualPath/4)
            else:
                if (measureCount + (actualPath*4)) <= 4:
                    path.append(actualPath)
                    measureCount += (actualPath*4)
                else:
                    path.append((4 - measureCount)/4)
                    measureCount = 0
                    path.append(actualPath)
                    measureCount += (actualPath*4)
            
            parent = tree[rdm][0]
    if path[0] < 1:
        path[0] = 1/path[0]
    
    return path;

# %% [markdown]
# ### Example
# ##### In the following cell we create a random rythm based on the path generated above.

# %%
path = get_path(freq);
print (path)
path_rhythm = create_percussion(time_sig = '4/4')
print(path_rhythm)
path_rhythm = rhythm_from_sequence(path, rhythm=path_rhythm)
path_rhythm.show()
#play(path_rhythm)
# Out:
# [2, 2, 8, 4.0, 8, 2, 6.0, 8, 8, 2, 8, 6.0, 8, 8, 4, 8, 4.0, 8, 8, 8, 2, 6.0, 8, 8, 8, 2, 2, 2, 2.0, 4, 4, 2, 2, 4.0, 8, 8, 2, 4, 1, 8, 1.0, 2, 4, 2, 8, 8, 2, 4, 2.0, 8, 1, 2, 5.0, 8, 8.0, 16, 4, 4, 4, 2, 2.0, 8, 8, 1, 8, 7.0, 8, 2, 4, 2.0, 4, 2, 4, 6.0, 8, 4, 2, 2, 2, 2, 2, 8, 2.0, 8, 2, 6.0, 8, 8, 2, 2, 4, 4, 4.0, 8, 2, 6.0, 16, 2, 4, 4, 6.0, 8, 2, 1, 2, 3.0, 4, 8, 4.0, 8, 2, 4, 2.0, 4, 2, 2, 8, 8, 8, 2, 4, 2, 0.5, 4, 4, 2, 6.0, 8, 8, 1, 4, 2, 0.5, 1.0, 8, 2, 6.0, 16, 2, 8, 4, 2, 8, 4, 4.0, 8, 8, 4, 2, 8, 2, 8, 8, 4, 4, 2, 6.0, 16, 2, 8, 4, 2.0, 8, 2, 6.0, 16, 4, 8, 4, 8, 2, 1, 4, 1.0, 2, 2]
# <music21.stream.Stream 0x7ffccc968820>

# %% [markdown]
# # Music generation
# ##### We then decided to put melody, rhythm and chords together and add functions/rules in order to end up with a partition that makes sense. To do so we created an ensemble of functions that would allow us to generate a partition containing a melody, chords and a corresponding base note for the chords.

# %% [markdown]
# ## Bass Algorithm
# ##### This function will find the chords based on a scale and the bass note of the scale. The number of chords generated is dependent on the parameter chordsNbr.

# %%
def copyChordsArray(_array): # only with Chord objects
    a = [];
    for i in range(len(_array)):
        a.append(_array[i].copy());       
    return a;

# %%
def copyNotesArray(_array): # only with Music21.Notes or Music21.Rest objects
    a = [];
    for i in range(len(_array)):
          if type(_array[i]) is note.Note:
                a.append(note.Note(pitch = _array[i].pitch.name, octave = _array[i].octave, quarterLength = _array[i].quarterLength));       
          else:
                a.append(note.Rest(quarterLength = _array[i].quarterLength));       
    return a;

# %%
def getEmptyPart(_quarterLength):
    cPart = stream.Part();
    cPart.append(note.Rest(quarterLength = _quarterLength));
    return cPart;

# %%
getEmptyPart(40).show()

# %%
def getBassChords(_scale, _chordsNbr = 4, _octaveRegion = 2):
    
    bassChords = []; # stores Chord objects
    
    startBassNote = note.Note(pitch = _scale.baseNote.pitch.name, octave = _octaveRegion);
    
    bassChords.append(Chord(startBassNote, _scale));   # bassChords[0]

    #Generation of the chords based on a random algorithm 
    for i in range(_chordsNbr-1): 

        # Bass Rules
        nr = NotesRange();
        nr.addChanceToNotesWithoutOctave(_scale.getNotesWithoutOctave()); # notes of the scale

        if _scale.isMinor():
            nr.multiplyChanceToNotesWithoutOctave([_scale.getTone(2)], _probability = 0);
        if _scale.isMajor():
            nr.multiplyChanceToNotesWithoutOctave([_scale.getTone(7)], _probability = 0);

        nr.multiplyChanceToNotesWithoutOctave(bassChords[i].getNotesWithoutOctave(), _probability = 3); # notes of the chord from the bassNotes[i]
        nr.multiplyChanceToNotesWithoutOctave([bassChords[i].baseNote], _probability = 0); # playing the same bassNotes[i] again
        nr.multiplyByFunction(intervalFunction(6), note.Note(pitch = 6, octave = _octaveRegion)); # range, to stay in the octaveRegion

        bassChords.append(Chord(nr.pickRandomNote(), _scale)); #bassChords[i+1]
        
    return bassChords;

# %% [markdown]
# ### Show bass
# ##### This function will create a score and two streams. The first two parameters will be inserted in the stream. The score is shown and played if the corresponding parameter is true.

# %%
def showBass(_bassChords, _bassNotes, _play = False):
       
    print("\nChords:")
    score = stream.Score()

    measureBassNotes = stream.Part();
    measureBassChords = stream.Part();

    score.insert(0, measureBassChords);
    score.insert(0, measureBassNotes);
     
    for i in range(len(_bassNotes)):
        print(i, _bassChords[i].getText(), _bassChords[i].getNotesWithoutOctave());  
        measureBassChords.append(_bassChords[i].getChordObject());
        measureBassNotes.append(_bassNotes[i]);

    score.show();
    if _play == True:
        play(score);

# %% [markdown]
# ## MixMelodyChordsAndBass
# ##### The function bellow creates streams for the melody, the chords and the bass notes. Then we create a score to which we insert those streams. The streams will consist of the corresponding parameters. Furthermore we add a tempo and an option to play the score or not.

# %%
def getBassChordsPart(_bassChords, _chordsRythm = [1,1,1,0.5,0.5], _chordsRythmType  = "", _octave = 3):
    cPart = stream.Part();
    
    for i in range(len(_bassChords)):

        #partBassChords.append(_bassChords[i].getChordObject(_quarterLength = 4));
        
        for k in range(len(_chordsRythm)):
            
            if _chordsRythm[k] < 0:
                cPart.append(note.Rest(quarterLength = abs(_chordsRythm[k])));
            else:
                if (_chordsRythmType == "arpeggiated"):  

                    bassChordsNotes = _bassChords[i].getNotesWithOctaveIncreasingOrder(_octave = _octave, _quarterLength = _chordsRythm[k]);
                    cPart.append(bassChordsNotes[k%len(bassChordsNotes)]);

                elif (_chordsRythmType == "arpeggiatedWithOctave"):
                    bassChordsNotes = _bassChords[i].getNotesWithOctaveIncreasingOrder(_octave = _octave, _quarterLength = _chordsRythm[k]);
                    cPart.append(bassChordsNotes[k%len(bassChordsNotes)].transpose(12*round((k-1)/len(bassChordsNotes))));
                else:
                    cPart.append(_bassChords[i].getChordObject(_quarterLength = _chordsRythm[k], _octave = _octave));
                
    return cPart;

# %%
def mixMelodyChordsAndBass(_melodyNotes, _bassChords, _bassNotes, _tempo = 60, _play = False, _chordsRythm = [1,1,1,0.5,0.5], _chordsRythmType  = "", _octave = 3):
    
    # Creation of the score
    score = stream.Score()
     
    # Creation of the streams    
    partMelodyNotes = stream.Part();
    partBassChords = stream.Part();
    partGuitarChords = stream.Part();
    partBassNotes = stream.Part();  
    
    # Definition of the tempo for the whole score
    partBassNotes.append(tempo.MetronomeMark(number = _tempo)); 
    
    # Insertion of the streams in the scores
    score.insert(0, partMelodyNotes); 
    score.insert(0, partBassChords);
    score.insert(0, partGuitarChords); 
    score.insert(0, partBassNotes);
      
    # Addition of the chords and bass notes to the streams
    for i in range(len(_bassNotes)):
        print(i, _bassChords[i].getText(), _bassChords[i].getNotesWithoutOctave());  
        
        _bassNotes[i].quarterLength = 4;
        partBassNotes.append(_bassNotes[i]);
        partBassChords.append(_bassChords[i].getChordObject(_quarterLength = 4));
        
        for k in range(len(_chordsRythm)):
            if (_chordsRythmType == "arpeggiated"):   
                bassChordsNotes = _bassChords[i].getNotesWithOctave(_octave = _octave, _quarterLength = _chordsRythm[k]);
                partGuitarChords.append(bassChordsNotes[k%len(bassChordsNotes)]);
                
            elif (_chordsRythmType == "arpeggiatedWithOctave"):
                bassChordsNotes = _bassChords[i].getNotesWithOctaveIncreasingOrder(_octave = _octave, _quarterLength = _chordsRythm[k]);
                partGuitarChords.append(bassChordsNotes[k%len(bassChordsNotes)].transpose(12*round((k-1)/len(bassChordsNotes))));
            else:
                partGuitarChords.append(_bassChords[i].getChordObject(_quarterLength = _chordsRythm[k], _octave = _octave));
                
            
               
    
    # Addition of notes from the melody to the corresponding stream
    for i in range(len(_melodyNotes)):
        partMelodyNotes.append(_melodyNotes[i]);
    
    # The score is shown and played if the boolean parameter
    score.show();
    if _play == True:
        play(score);
    
    return score;

# %% [markdown]
# ## Melody with chords function
# ##### The following functions takes as parameteres a scale, a chrod and durations. The code in the cell is commented in order to understand the whole process.

# %%
def getMelody(_scale, _bassChords, _durations, _season = "spring",  _octave = 4, _scaleCoef = 0):
        
    melodyNotes = [];
      
    measureCounter = 0;
    quarterLengthCounter = 0;
    
    # start note of the melody, a random note belonging to the first chord
   # if _season == "spring":
       
   # elif _season == "summer":
        
   # elif _season == "autumn":
      
   # elif _season == "winter":
        
        
    startNote = _bassChords[0].getNotesWithOctave(_octave)[random.randint(0, len(_bassChords[0].getNotesWithoutOctave())-1)];

    # loop through the _durations
    for i in range(len(_durations)):
            
        # define dur
        dur = abs(_durations[i]);
                
        # Rest convention from the get_path() function
        isRest = dur < 1;
        if isRest:
            dur *= 4;
        else:
            dur /= 4;
                    
        # Actualize the counters
        quarterLengthCounter += dur;
        measureCounter = int(quarterLengthCounter/4-0.01);
        
        # Checks if arrived at the end of the _bassChords
        if measureCounter > len(_bassChords)-1:
            # print("finished", measureCounter, len(_bassChords))
            break;
        
        # Rest
        if isRest:                            
            melodyNotes.append(note.Rest(quarterLength = dur));
               
        # Note
        else:                               
            # First note
            if i == 0:          
                melodyNotes.append(note.Note(pitch = startNote.pitch, quarterLength = dur));
            
            # Following notes
            else:       
                # Find previous melody note
                previousMelodyNote = note.Note();
                for u in range(len(melodyNotes)):
                    if type(melodyNotes[u]) is note.Note:
                        previousMelodyNote = melodyNotes[u];
                        break;
                    
                # Melody Rules            
                nrScale = NotesRange();
                nrScale.addChanceToNotesWithoutOctave(_scale.getNotesWithoutOctave(), _probability = _scaleCoef/dur**2)
                nrScale.multiplyByFunction(intervalFunction(3), previousMelodyNote); # to stay close to the previous note
                 
                nr = NotesRange();
                nr.addChanceToNotesWithoutOctave(_bassChords[measureCounter].getNotesWithoutOctave(), _probability = 10);
               
                nr.multiplyByFunction(intervalFunction(6), previousMelodyNote); # to stay close to the previous note
                nr.multiplyByFunction(gaussFunction(12), startNote); # to stay at the melody "height"
                
                nr.addOtherNotesRange(nrScale);
                
                # Pick next melody note
                n = nr.pickRandomNote();
                n.quarterLength = dur;
                melodyNotes.append(n)
                
                # print("chose Note", n.pitch, "chord", _bassChords[measureCounter].getText());
    
    return melodyNotes;

# %% [markdown]
# ##### The function below converts notes into a stream.

# %%
def getStreamFromNotes(_notes):
    s = stream.Stream();
    s.timeSignature = meter.TimeSignature('4/4');
    s.append(_notes);
    return s;

# %%
def getPartFromNotes(_notes):
    p = stream.Part();
    p.append(getStreamFromNotes(_notes));
    return p;

# %% [markdown]
# ### Scale
# ##### In the following cell a random scale will be generated using the scale constructor. Therefore every time the cell is run a new scale will be generated.

# %%
theScale = Scale(_randomBase = True, _randomMinorMajorScale = True);
theScale.show();
# Out:
# G# major [0, 2, 4, 5, 7, 9, 11]

# %% [markdown]
# ### Bass
# ##### In the following cell, we create a score with a scale and chords.

# %%
theOctaveRegion = 2;
theChordsNbr = 4;

theBassChords = getBassChords(theScale, theChordsNbr, theOctaveRegion);
for i in range(len(theBassChords)):
    theBassChords.append(theBassChords[i].copy());

theBassNotes = [note.Note(pitch = c.baseNote.pitch.name, octave = theOctaveRegion) for c in theBassChords];

showBass(theBassChords, theBassNotes, _play = True);
# Out:
# Chords:
# 0 G#  [<music21.note.Note G#>, <music21.note.Note C>, <music21.note.Note E->]
# 1 C#  [<music21.note.Note C#>, <music21.note.Note F>, <music21.note.Note G#>]
# 2 G#  [<music21.note.Note G#>, <music21.note.Note C>, <music21.note.Note E->]
# 3 C m [<music21.note.Note C>, <music21.note.Note E->, <music21.note.Note G>]
# 4 G#  [<music21.note.Note G#>, <music21.note.Note C>, <music21.note.Note E->]
# 5 C#  [<music21.note.Note C#>, <music21.note.Note F>, <music21.note.Note G#>]
# 6 G#  [<music21.note.Note G#>, <music21.note.Note C>, <music21.note.Note E->]
# 7 C m [<music21.note.Note C>, <music21.note.Note E->, <music21.note.Note G>]

# %% [markdown]
# ### Melody
# ##### In the following cell we will mix the generated rythme and the generated sequence of notes.

# %%
theDurations = get_path(freq);

print("theDurations",theDurations);
theMelody = getMelody(theScale, theBassChords, theDurations, _octave = 6)

melodyStream = getStreamFromNotes(theMelody);
melodyStream.show();
# Out:
# theDurations [2, 4, 2, 4, 4.0, 8, 4, 4, 4, 8, 4.0, 8, 2, 6.0, 8, 8.0, 16, 0.25, 8, 4, 2, 8, 6.0, 16, 1, 2, 0.25, 4, 0.3125, 0.5, 1, 2, 4, 1.0, 8, 2, 4, 2.0, 16, 8, 4, 4, 2, 2, 2, 4, 6.0, 16, 4, 4, 4, 2, 2, 2, 8, 4, 2, 4, 4, 4, 4, 8, 2, 2, 4, 4, 8, 2, 2, 2, 2, 4, 2, 6.0, 8, 4, 2, 2.0, 4, 4, 2, 6.0, 8, 1, 2, 2, 3.0, 4, 2, 2, 8, 2, 2, 2, 2, 4, 4.0, 16, 4, 2, 8, 2, 2, 14.0, 16, 4, 2, 8, 2, 8, 2, 2, 4, 2, 8, 2, 4.0, 8, 2, 6.0, 8, 4, 4.0, 8, 8, 2, 4, 2, 2, 4, 2, 8, 2, 6.0, 8, 4, 4, 2, 2, 2, 2, 2, 2, 2, 2.0, 8, 4, 2, 2.0, 4, 8, 4, 4, 4, 8, 2, 14.0, 16, 0.25, 8, 4.0, 8, 8, 0.5, 2, 6.0, 8, 1, 2, 2, 2, 1.0, 2, 4, 8, 2, 4, 2, 2, 8, 2, 2, 2, 10.0, 16, 4, 4, 2, 4, 2, 2, 2, 8, 2, 1, 1.0, 8, 8, 2]

# %% [markdown]
# ### Mix melody and chords
# ##### In the following cell we will mix the melody and the chords in order to create a 4 staff piece.

# %%
bpm = 100;
theScore = mixMelodyChordsAndBass(theMelody, theBassChords, theBassNotes, bpm, _play = False, _chordsRythm = [1/2 for k in range(0,4*2)], _chordsRythmType  = "arpeggiatedWithOctave");
# Out:
# 0 G#  [<music21.note.Note G#>, <music21.note.Note C>, <music21.note.Note E->]
# 1 C#  [<music21.note.Note C#>, <music21.note.Note F>, <music21.note.Note G#>]
# 2 G#  [<music21.note.Note G#>, <music21.note.Note C>, <music21.note.Note E->]
# 3 C m [<music21.note.Note C>, <music21.note.Note E->, <music21.note.Note G>]
# 4 G#  [<music21.note.Note G#>, <music21.note.Note C>, <music21.note.Note E->]
# 5 C#  [<music21.note.Note C#>, <music21.note.Note F>, <music21.note.Note G#>]
# 6 G#  [<music21.note.Note G#>, <music21.note.Note C>, <music21.note.Note E->]
# 7 C m [<music21.note.Note C>, <music21.note.Note E->, <music21.note.Note G>]

# %% [markdown]
# ### Instruments
# ##### In the following cell, the instruments were changed. The top staff of the score will be played by the violin, the second one by the contrabass, the third by the guitar and the last one by the piano. Furthermore we decided to play the second and fourth staffs a little quieter than the others.

# %%
theScore[0].insert(0, instrument.Violin())
theScore[1].insert(0, instrument.Contrabass())
theScore[2].insert(0, instrument.Guitar())
theScore[0].insert(0, dynamics.Dynamic(0.6))
theScore[1].insert(0, dynamics.Dynamic(0.3))
theScore[2].insert(0, dynamics.Dynamic(1))
theScore[3].insert(0, dynamics.Dynamic(0.8))

#play(theScore)

# %% [markdown]
# # Modified audio samples
# ##### Furthermore to give more sense to our seasons we have decided that in the end we would add some audio files representing each season. For example, for the spring we will be adding sounds of singing birds. Those audio files are taken from Youtube and the background noises are deleted by modifying the audio file using Audacity. It is even possible to change the pitch of these files. This technique will very likely be explored more once we will assemble the score and the audio files to see if the pitch of the audio can be adjusted to the scale of the piece. We will show you an example of how we have managed to this and try to insert the audio before and after the modification.

# %% [markdown]
# #### How to get rid of background noise
# ##### The steps to get rid of the backgroud noise are the following. First what we can see on the image below is that the bottom two lines represent the same audio sample as the bottom two except they don't contain any background noises anymore. Therefore we will show the steps of how to recreate the top two lines while starting with the bottom two lines.

# %% [markdown]
# ![](Pic1.png)

# %% [markdown]
# ##### To start zoom in on a section with only background noise and select as long of a segment as possible. As you can see the lighter segment has been selected.

# %% [markdown]
# ![](Pic2.png)

# %% [markdown]
# ##### Now go onto 'Effect' and select 'Raush-Verminderung' ('Noise Reduction')

# %% [markdown]
# ![](Pic3.png)

# %% [markdown]
# ##### You will see the following window poping up. Try to manipulate the three number ('Rausch-Verminderung (dB)', 'Empfinldichkeit' and 'Frequenz-Glättung (Bänder)') in order to get rid of your background noise. Everytime you change these numbers press 'Vorhören' in order to listen to you selected sequence with those changes. Once you are satisfied with the result press 'OK'

# %% [markdown]
# ![](Pic4.png)

# %% [markdown]
# ##### You can now see that all the background noise from the selected area has disappreared.

# %% [markdown]
# ![](Pic5.png)

# %% [markdown]
# ##### Now select the whole audio sample and go back onto 'Effect' and select 'Rausch-Verminderung wiederholen'. This step will apply the background noise cancelling previously formated to the whole audio sample.

# %% [markdown]
# ![](Pic6.png)

# %% [markdown]
# ##### As we can see now we have achieved our goal. All four lanes look the same.

# %% [markdown]
# ![](Pic7.png)

# %% [markdown]
# #### How to change the pitch
# ##### Select the part of the audio that you want to change the pitch of. Then go search for 'Change Pitch' (or 'Tonhöhe ändern' in the previous pictures) under the 'Effect' bar. And decide which pitch you would like.

# %% [markdown]
# #### Examples
# ##### BirdOriginal is the original sound taken from youtube before we modified it and got rid of the background noise. As you can hear there is a lot of background noise in this audio sample. The second one (Bird.wav) is the sample we got after doing all the steps mentionned previously. As you can hear there is hardly anymore background noise. The third audio sample (bird2.wav) is the same as the second one except it is in a different pitch. As you can hear it the birds seem to have a lower pitch in the thirs audio sample.
# ##### Remarque : other audio files will be used in the making of our final piece however as the files are quite big it would not be possible to upload them on the moodle page.

# %%
Audio('BirdOriginal.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('Bird.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('bird2.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **3) Outlook: Macroform**
# ##### To conclude we have computed multiple functions in order to create an aleatoric but structured piece that would be played by multiple instruments. As we noted in milestone 1, each season will be characterised by a specific instrument, scale and appropriate rhythm. We therefore made sure to be able to modify the speed (bpm), the rhythm (more full notes or more half notes for example), the instruments and the scales in order to adapt the generated piece to each season. In our code below you will be able to see many examples illustrating each step of our work with graphical representations in the form of graphs, scores, or even screenshots of the workflow on Audacity (see section ‘Modified audio samples’). In future steps we will have to review the use of the guitar as it does not seem to add information to our piece. We might be trying out other rhythms for the guitar. In the previous milestone we also mentioned that we will be using percussion throughout the four seasons. As of right now we have not generated the rhythm for this. We will however try to incorporate it in future steps. This will not be a random rhythm and we will try to make it specific to each season. We will also work on the generation of the scores for the four seasons by using the already generated code and by finding the right frequencies to use for each note value to represent each season the best. Other parameters might also be considered. Once we are satisfied with the results we will be using another program which we will use to put all our mouvements back to back and add the audio files to them. In the cells below we have already started to try to assemble a piece for the spring movement but it is not yet complete.

# %% [markdown]
# # The piece
# ##### The piece itself will be composed of 4 mouvements representing the 4 seasons. Each movement is characterised by its instruments, its partition and a sound that we will add on top of the aleatoricly generated piece. Furthermore we will make sure that each movement has specificities that represent the respective season. For example, we will try to compose a more slow and heavy sound for the winter. This specific assembly will be done in future steps of our project.

# %% [markdown]
# ## Spring

# %% [markdown]
# ##### Here we have already tried to write a score for the Spring. During the spring, the instruments being played are the piano the guitar, and the piccolo. We also chose some frequencies for the rythme that would match a spring like atmosphere. The scale chosen here is E major as it is this one that Vivaldi chose for his spring movement himself.

# %%
theBpm = 100;

# %%
theScale = Scale(note.Note('E'), scalesIntervalDictionnary["major"]);
theScale.show();
# Out:
# E major [0, 2, 4, 5, 7, 9, 11]

# %% [markdown]
# ### First movement : Alone and Lost

# %%
## Intro - 4 measures
# Bass and chords
theBassChords = getBassChords(theScale, _chordsNbr = 4, _octaveRegion = 2);
theBassNotes = [note.Note(pitch = c.baseNote.pitch.name, octave = 2, quarterLength = 4) for c in theBassChords];

theBassNotesPart = getPartFromNotes(theBassNotes);
theBassChordsRythmPart = getBassChordsPart(theBassChords, [-2, 2], "", _octave = 3);

theScore = stream.Score();
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, theBassNotesPart);

introScore = theScore;

# %%
#introScore.show()

# %%
#play(introScore)

# %%
## Outro - 4 measures
# Bass and chords

theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotes));
theBassChordsRythmPart = getBassChordsPart(theBassChords, [-2, 2], "", _octave = 3);

theScore = stream.Score();
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, theBassNotesPart);

outroScore = theScore;

# %%
## Verse - 8 measures 
# Bass & Chords

theBassNotesX2 = copyNotesArray(theBassNotes) + copyNotesArray(theBassNotes);
theBassChordsX2 = theBassChords + copyChordsArray(theBassChords);

theBassChordsPart = getBassChordsPart(theBassChordsX2, [-2, 2], "", _octave = 3);
theBassNotesPart = getPartFromNotes(theBassNotesX2);

# Melody
theFrequencies = [10, 30, 50, 10, 10, 10, 2, 1];
theMelody = getMelody(theScale, theBassChordsX2, get_path(theFrequencies), _octave = 6,  _scaleCoef = 10);
theMelodyPart = getPartFromNotes(theMelody);

theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

verseScore = theScore;

# %%
#verseScore.show();

# %%
#play(verseScore);

# %%
## Verse 2- 8 measures 
# Bass & Chords
# Same than verse 1 except the melody

theBassChordsPart = getBassChordsPart(copyChordsArray(theBassChordsX2), [-2, 2], "", _octave = 3);
theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotesX2));

# Melody
theMelody = getMelody(theScale, theBassChordsX2, get_path(theFrequencies), _octave = 6, _scaleCoef = 10);
theMelodyPart = getPartFromNotes(theMelody);

theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

verse2Score = theScore;

# %%
#verse2Score.show();

# %%
## Chorus - 8 measures

theBassChords = getBassChords(theScale, _chordsNbr = 4, _octaveRegion = 2);
theBassNotes = [note.Note(pitch = c.baseNote.pitch.name, octave = 2, quarterLength = 4) for c in theBassChords];


theFrequencies = [0, 30, 30, 10, 0, 0, 0, 0];
theMelodyNotes = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 5, _scaleCoef = 0);
theMelodyNotes = theMelodyNotes + copyNotesArray(theMelodyNotes);
theMelodyPart = getPartFromNotes(theMelodyNotes);

# theMelodyNotesHigh = [note.Note(quarterLength = x.quarterLength, octave = x.octave-1, pitch = x.pitch.name) for x in theMelodyNotes];

theMelodyNotesHigh = [x.transpose(12) for x in theMelodyNotes];
theMelodyPartHigh = getPartFromNotes(theMelodyNotesHigh);

theBassNotesX2 = theBassNotes + copyNotesArray(theBassNotes);
theBassChordsX2 = theBassChords + copyChordsArray(theBassChords);

theBassNotesPart = getPartFromNotes(theBassNotesX2);
theBassChordsPart = getBassChordsPart(theBassChordsX2, [1, 1, 1, 1], "", _octave = 3);
theBassChordsRythmPart = getBassChordsPart(theBassChordsX2, [1/2 for x in range(2*4)], "arpeggiatedWithOctave", _octave = 2);



theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, theMelodyPartHigh);
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

chorusScore = theScore;

# %%
#chorusScore.show()

# %%
#play(chorusScore)

# %%
### Chorus2 - 8 measures
# same as the first chorus
## !! execute just after the first chorus !!


theMelodyPart = getPartFromNotes(copyNotesArray(theMelodyNotes));
theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotesX2));
theBassChordsPart = getBassChordsPart(theBassChordsX2, [1, 1, 1, 1], "", _octave = 3);
theBassChordsRythmPart = getBassChordsPart(theBassChordsX2, [1/2 for x in range(2*4)], "arpeggiatedWithOctave", _octave = 2);

#theMelodyNotesHigh = [note.Note(quarterLength = x.quarterLength, octave = x.octave-1, pitch = x.pitch.name) for x in theMelodyNotes];
theMelodyNotesHigh = [x.transpose(12) for x in theMelodyNotes];
theMelodyPartHigh = getPartFromNotes(theMelodyNotesHigh);


theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, theMelodyPartHigh);
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

chorus2Score = theScore;

# %%
#chorus2Score.show()

# %%
#play(chorus2Score)

# %%
# Concat the scores
theScore = concatScores(introScore, verseScore);
theScore = concatScores(theScore, chorusScore);
theScore = concatScores(theScore, verse2Score);
theScore = concatScores(theScore, chorus2Score);
theScore = concatScores(theScore, outroScore);

# Instruments and dynamics
theScore[0].insert(0, instrument.Piccolo())
theScore[1].insert(0, instrument.Flute())
theScore[2].insert(0, instrument.Piano())
theScore[3].insert(0, instrument.Guitar())
theScore[4].insert(0, instrument.Guitar())


theScore[0].insert(0, dynamics.Dynamic(0.5))
theScore[1].insert(0, dynamics.Dynamic(0.5))
theScore[2].insert(0, dynamics.Dynamic(0.5))
theScore[3].insert(0, dynamics.Dynamic(0.5))
theScore[4].insert(0, dynamics.Dynamic(0.5))

# %%
theScore.show();

# %%
# play(theScore)

# %%
mm = theScore.write('midi', 'mm7.midi')

# %% [markdown]
# ## Summer

# %%
# instruments : piano, percussion, guitar ???
# scale: G minor

# %%
theBpm = 130;

# %%
theScale = Scale(note.Note('G'), scalesIntervalDictionnary["minor"]);
theScale.show();
# Out:
# G minor [0, 2, 3, 5, 7, 8, 10]

# %%
## Intro - 4 measures
# Bass and chords
theBassChords = getBassChords(theScale, _chordsNbr = 4, _octaveRegion = 2);
theBassNotes = [note.Note(pitch = c.baseNote.pitch.name, octave = 2, quarterLength = 4) for c in theBassChords];

theBassNotesPart = getPartFromNotes(theBassNotes);
theBassChordsPart = getBassChordsPart(theBassChords, [4], "", _octave = 3);
theBassChordsRythmPart = getBassChordsPart(theBassChords, [1 for x in range(4)], "arpeggiated", _octave = 2);

theScore = stream.Score();
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);
theScore.insert(0, getEmptyPart(4*4));

introScore = theScore;

# %%
## Outro - 4 measures
# Bass and chords

theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotes));
theBassChordsPart = getBassChordsPart(theBassChords, [4], "", _octave = 3);
theBassChordsRythmPart = getBassChordsPart(theBassChords, [1 for x in range(4)], "arpeggiated", _octave = 2);

theScore = stream.Score();
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);
theScore.insert(0, getEmptyPart(4*4));

outroScore = theScore;

# %% [markdown]
# ### Summer - Verse
# 8 measures,

# %%
theBassNotesX2 = copyNotesArray(theBassNotes) + copyNotesArray(theBassNotes);
theBassChordsX2 = theBassChords + copyChordsArray(theBassChords);

theBassChordsPart = getBassChordsPart(theBassChordsX2, [4], "", _octave = 3);
theBassNotesPart = getPartFromNotes(theBassNotesX2);

theBassChordsRythmPart1 = getBassChordsPart(theBassChords, [1 for x in range(1*4)], "arpeggiated", _octave = 2);
theBassChordsRythmPart2 = getBassChordsPart(theBassChords, [1/2 for x in range(2*4)], "arpeggiated", _octave = 2);

# Melody
theFrequencies = [1, 0, 0, 0, 0, 0, 0, 0];
#theFrequencies = [30, 50, 50, 10, 5, 3, 0, 0];
theMelody = getMelody(theScale, theBassChordsX2, get_path(theFrequencies), _octave = 4,  _scaleCoef = 10);
#theMelody = getMelody(theScale, theBassChordsX2, get_path(theFrequencies), _octave = 4,  _scaleCoef = 10);
theMelodyPart = getPartFromNotes(theMelody);

theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, concatParts(theBassChordsRythmPart1,theBassChordsRythmPart2));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);
theScore.insert(0, getEmptyPart(8*4));

verseScore = theScore;

# %%
#verseScore.show()

# %%
#play(verseScore)

# %% [markdown]
# ### Summer - Second Verse
# 8 measures
# Same chods and rythm as the first verse, except for the melody which is new.

# %%
theBassChordsPart = getBassChordsPart(theBassChordsX2, [4], "", _octave = 3);
theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotesX2));

theBassChordsRythmPart1 = getBassChordsPart(theBassChords, [1 for x in range(1*4)], "arpeggiated", _octave = 2);
theBassChordsRythmPart2 = getBassChordsPart(theBassChords, [1/2 for x in range(2*4)], "arpeggiated", _octave = 2);

# Melody
theFrequencies = [1, 0, 0, 0, 0, 0, 0, 0];
paaath = get_path(theFrequencies);
theMelody = getMelody(theScale, theBassChordsX2, paaath, _octave = 4, _scaleCoef = 10);
theMelodyPart = getPartFromNotes(theMelody);
theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, concatParts(theBassChordsRythmPart1,theBassChordsRythmPart2));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);
theScore.insert(0, getEmptyPart(8*4));

verse2Score = theScore;

# %%
verse2Score.show()

# %% [markdown]
# ### Summer - Chorus

# %%
## Chorus - 8 measures

theBassChords = getBassChords(theScale, _chordsNbr = 4, _octaveRegion = 2);
theBassNotes = [note.Note(pitch = c.baseNote.pitch.name, octave = 2, quarterLength = 4) for c in theBassChords];


theFrequencies = [40, 68, 22, 0, 0, 0, 0, 16];
#theFrequencies = [0, 40, 30, 10, 0, 0, 0, 0];
theMelodyNotes = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 4, _scaleCoef = 0);
theMelodyNotes = theMelodyNotes + copyNotesArray(theMelodyNotes);
theMelodyPart = getPartFromNotes(theMelodyNotes);

theBassNotesX2 = theBassNotes + copyNotesArray(theBassNotes);
theBassChordsX2 = theBassChords + copyChordsArray(theBassChords);

theBassNotesPart = getPartFromNotes(theBassNotesX2);
theBassNotesPart2 = getPartFromNotes(copyNotesArray(theBassNotesX2));
theBassChordsPart1 = getBassChordsPart(theBassChordsX2, [1/1 for x in range(1*4)], "", _octave = 3);
theBassChordsPart2 = getBassChordsPart(theBassChordsX2, [1/1 for x in range(1*4)], "", _octave = 3);
theBassChordsRythmPart = getBassChordsPart(theBassChordsX2, [1/4 for x in range(4*4)], "arpeggiated", _octave = 2);

theScore = stream.Score(); 
theScore.insert(0, theMelodyPart);
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, theBassChordsPart2);
theScore.insert(0, theBassChordsPart1);
theScore.insert(0, theBassNotesPart);
theScore.insert(0, theBassNotesPart2);

chorusScore = theScore;

# %%
#chorusScore.show()

# %%
#play(chorusScore)

# %% [markdown]
# ### Summer - Second Chorus

# %%
## Chorus2 - 8 measures
# same as the first chorus
## !! execute just after the first chorus !!

theMelodyPart = getPartFromNotes(copyNotesArray(theMelodyNotes));
theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotesX2));
theBassNotesPart2 = getPartFromNotes(copyNotesArray(theBassNotesX2));
theBassChordsPart1 = getBassChordsPart(theBassChordsX2, [1/1 for x in range(1*4)], "", _octave = 3);
theBassChordsPart2 = getBassChordsPart(theBassChordsX2, [1/1 for x in range(1*4)], "", _octave = 3);
theBassChordsRythmPart = getBassChordsPart(theBassChordsX2, [1/4 for x in range(4*4)], "arpeggiated", _octave = 2);


theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, theBassChordsPart2);
theScore.insert(0, theBassChordsPart1);
theScore.insert(0, theBassNotesPart);
theScore.insert(0, theBassNotesPart2);

chorus2Score = theScore;

# %%
#play(chorus2Score)

# %%
# Concat the scores
theScore = concatScores(introScore, verseScore, theBpm);
theScore = concatScores(theScore, chorusScore);
theScore = concatScores(theScore, verse2Score);
theScore = concatScores(theScore, chorus2Score);
theScore = concatScores(theScore, outroScore);

# Tempo
theScore.insert(0, tempo.MetronomeMark(number = theBpm))

# Instruments and dynamics
theScore[0].insert(0, instrument.Saxophone())
theScore[1].insert(0, instrument.AltoSaxophone())
theScore[2].insert(0, instrument.Trombone())
theScore[3].insert(0, instrument.Horn())
theScore[4].insert(0, instrument.Tuba())
theScore[5].insert(0, instrument.Piano())


theScore[0].insert(0, dynamics.Dynamic(0.4))
theScore[1].insert(0, dynamics.Dynamic(0.4))
theScore[2].insert(0, dynamics.Dynamic(0.4))
theScore[3].insert(0, dynamics.Dynamic(0.4))
theScore[4].insert(0, dynamics.Dynamic(0.4))
theScore[5].insert(0, dynamics.Dynamic(1))

# %%
#theScore.show();

# %%
#play(theScore)

# %%
mm = theScore.write('midi', 'suuuumer7.midi')

# %% [markdown]
# ## Autumn

# %%
# instruments : piano, percussion, guitar, violin
# scale: F major

# %%
theBpm = 100;

# %%
theScale = Scale(note.Note('F4'), scalesIntervalDictionnary["major"]);
theScale.show();
# Out:
# F major [0, 2, 4, 5, 7, 9, 11]

# %%
## Intro - 4 measures
# Bass and chords
theBassChords = getBassChords(theScale, _chordsNbr = 4, _octaveRegion = 2);
theBassNotes = [note.Note(pitch = c.baseNote.pitch.name, octave = 2, quarterLength = 4) for c in theBassChords];

theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotes) + copyNotesArray(theBassNotes));
theBassChordsPart = getBassChordsPart(theBassChords + theBassChords, [4], "", _octave = 3);

theBassChordsRythmPart1 = getBassChordsPart(theBassChords, [2, -2], "", _octave = 2);
theBassChordsRythmPart2 = getBassChordsPart(theBassChords, [-2, 2], "", _octave = 3);

theBassChordsRythmPart3 = getBassChordsPart(theBassChords, [1, -1, 1, -1], "", _octave = 2);
theBassChordsRythmPart4 = getBassChordsPart(theBassChords, [-1, 1, -1, 1], "", _octave = 3);

theScore = stream.Score();
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, concatParts(theBassChordsRythmPart1, theBassChordsRythmPart3));
theScore.insert(0, concatParts(theBassChordsRythmPart2, theBassChordsRythmPart4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

introScore = theScore;

# %%
introScore.show()

# %%
#play(introScore)

# %%
## Outro - 4 measures
# Bass and chords

theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotes));
theBassChordsPart = getBassChordsPart(theBassChords, [4], "", _octave = 3);

theScore = stream.Score();
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0,  getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

outroScore = theScore;

# %%
outroScore.show()

# %%
## Thunderstorm - 4 measures 
# Bass & Chords

theBassChordsRythmPart1 = getBassChordsPart(theBassChords, [1, -1, 1, -1], "", _octave = 2);
theBassChordsRythmPart2 = getBassChordsPart(theBassChords, [-1, 1, -1, 1], "", _octave = 3);

theBassChordsPart = getBassChordsPart(theBassChords, [4], "", _octave = 3);
theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotes));

# Melody
theFrequencies = [5, 2, 0, 0, 0, 0, 0, 0];

theMelody = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 4,  _scaleCoef = 0);
theMelodyPart1 = getPartFromNotes(theMelody);

theMelody = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 5,  _scaleCoef = 0);
theMelodyPart2 = getPartFromNotes(theMelody);

theMelody = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 6,  _scaleCoef = 0);
theMelodyPart3 = getPartFromNotes(theMelody);

theMelody = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 7,  _scaleCoef = 20);
theMelodyPart4 = getPartFromNotes(theMelody);

theMelody = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 5,  _scaleCoef = 20);
theMelodyPart5 = getPartFromNotes(theMelody);

theMelody = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 6,  _scaleCoef = 20);
theMelodyPart6 = getPartFromNotes(theMelody);

theScore = stream.Score();
theScore.insert(0, theMelodyPart1);
theScore.insert(0, theMelodyPart2);
theScore.insert(0, theMelodyPart3);
theScore.insert(0, theMelodyPart4);
theScore.insert(0, theMelodyPart5);
theScore.insert(0, theMelodyPart6);
theScore.insert(0, theBassChordsRythmPart1);
theScore.insert(0, theBassChordsRythmPart2);
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

verseScore = theScore;

# %%
verseScore.show()

# %%
#play(verseScore)

# %%
#Thunderstorm goes away
## Thunderstorm - 4 measures 
# Bass & Chords

theBassChordsRythmPart = getBassChordsPart(theBassChords, [4], "", _octave = 2);

theBassChordsPart = getBassChordsPart(theBassChords, [4], "", _octave = 3);
theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotes));

# Melody
theFrequencies = [1, 0, 0, 0, 0, 0, 0, 0];

theMelody = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 4,  _scaleCoef = 0);
theMelodyPart = getPartFromNotes(theMelody);


theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));

versebisScore = theScore;

# %%
versebisScore.show()

# %% [markdown]
# #### Concat scores

# %%
# Concat the scores
theScore = concatScores(introScore, verseScore);
theScore = concatScores(theScore, versebisScore);
#theScore = concatScores(theScore, chorusScore);
#theScore = concatScores(theScore, verse2Score);
#theScore = concatScores(theScore, chorus2Score);
theScore = concatScores(theScore, outroScore);

# Tempo
theScore.insert(0, tempo.MetronomeMark(number = theBpm))

# Instruments and dynamics
theScore[0].insert(0, instrument.Glockenspiel())
theScore[1].insert(0, instrument.Glockenspiel())
theScore[2].insert(0, instrument.Glockenspiel())
theScore[3].insert(0, instrument.Glockenspiel())
theScore[4].insert(0, instrument.Glockenspiel())
theScore[5].insert(0, instrument.Glockenspiel())

theScore[6].insert(0, instrument.ReedOrgan())
theScore[7].insert(0, instrument.ReedOrgan())
theScore[8].insert(0, instrument.Bass())
theScore[9].insert(0, instrument.Bass())


theScore[0].insert(0, dynamics.Dynamic(0.4))
theScore[1].insert(0, dynamics.Dynamic(0.4))
theScore[2].insert(0, dynamics.Dynamic(0.4))
theScore[3].insert(0, dynamics.Dynamic(0.4))
theScore[4].insert(0, dynamics.Dynamic(0.4))
theScore[5].insert(0, dynamics.Dynamic(0.4))

theScore[6].insert(0, dynamics.Dynamic(0.4))
theScore[7].insert(0, dynamics.Dynamic(0.4))
theScore[8].insert(0, dynamics.Dynamic(0.4))
theScore[9].insert(0, dynamics.Dynamic(0.4))

# %%
theScore.show()

# %%
#play(theScore)

# %%
mm = theScore.write('midi', 'autumnn1.midi')

# %% [markdown]
# ## Winter

# %%
# instruments : piano, percussion, guitar, counterbasson
# scale:F minor

# %%
theBpm = 80;

# %%
theScale = Scale(note.Note('F4'), scalesIntervalDictionnary["minor"]);
theScale.show();
# Out:
# F minor [0, 2, 3, 5, 7, 8, 10]

# %%
## Intro - 4 measures
# Bass and chords
theBassChords = getBassChords(theScale, _chordsNbr = 4, _octaveRegion = 2);
theBassNotes = [note.Note(pitch = c.baseNote.pitch.name, octave = 2, quarterLength = 4) for c in theBassChords];

theBassNotesPart = getPartFromNotes(theBassNotes);
theBassChordsPart = getBassChordsPart(theBassChords, [4], "", _octave = 3);


theScore = stream.Score();
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

introScore = theScore;

# %%
introScore.show()

# %%
play(introScore)

# %%
## Outro - 4 measures
# Bass and chords

theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotes));
theBassChordsPart = getBassChordsPart(theBassChords, [4], "", _octave = 3);

theScore = stream.Score();
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

outroScore = theScore;

# %%
theBassChordsPart = getBassChordsPart(copyChordsArray(theBassChords), [4], "", _octave = 2);
theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotes));

theBassChordsRythmPart = getBassChordsPart(theBassChords, [1 for x in range(1*4)], "arpeggiated", _octave = 2);

# Melody
theFrequencies = [30, 50, 50, 10, 5, 3, 0, 0];
theMelody = getMelody(theScale, theBassChords, get_path(theFrequencies), _octave = 3,  _scaleCoef = 10);
theMelodyPart = getPartFromNotes(theMelody);

theScore = stream.Score();
theScore.insert(0, theMelodyPart);
theScore.insert(0, theBassChordsRythmPart);
theScore.insert(0, getEmptyPart(4*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

verseScore = theScore;

# %%
verseScore.show()

# %%
play(verseScore)

# %%
verseScore.show();

# %%
play(verseScore)

# %%
## Verse 2- 8 measures 
# Bass & Chords
# Same than verse 1 except the melody

theBassChordsPart = getBassChordsPart(copyChordsArray(theBassChordsX2), [-2, 2], "", _octave = 3);
theBassNotesPart = getPartFromNotes(copyNotesArray(theBassNotesX2));

# Melody
theMelody = getMelody(theScale, theBassChordsX2, get_path(theFrequencies), _octave = 6, _scaleCoef = 10);
theMelodyPart = getPartFromNotes(theMelody);

theScore = stream.Score();
theScore.insert(0, theMelodyPart)
theScore.insert(0, getEmptyPart(8*4));
theScore.insert(0, theBassChordsPart);
theScore.insert(0, theBassNotesPart);

verse2Score = theScore;

# %%
# Concat the scores
#theScore = concatScores(introScore, verseScore);
#theScore = concatScores(theScore, chorusScore);
#theScore = concatScores(theScore, verse2Score);
#theScore = concatScores(theScore, chorus2Score);
##theScore = concatScores(theScore, outroScore);

# Instruments and dynamics
theScore[0].insert(0, instrument.WindMac())
theScore[1].insert(0, instrument.WindMachine())
theScore[2].insert(0, instrument.WindMachine())
theScore[3].insert(0, instrument.WindMachine())
theScore[4].insert(0, instrument.WindMachine())
theScore[5].insert(0, instrument.WindMachine())
theScore[6].insert(0, instrument.WindMachine())
theScore[7].insert(0, instrument.WindMachine())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-544-25fc55505d21> in <module>
#       7
#       8 # Instruments and dynamics
# ----> 9 theScore[0].insert(0, instrument.HironobuAkyiama())
#      10 theScore[1].insert(0, instrument.WindMachine())
#      11 theScore[2].insert(0, instrument.WindMachine())
#
# AttributeError: module 'music21.instrument' has no attribute 'HironobuAkyiama'

# %%
theScore.show()

# %%
play(theScore)
